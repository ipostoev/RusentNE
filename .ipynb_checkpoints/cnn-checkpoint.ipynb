# %%
from nltk.corpus import stopwords
from pymystem3 import Mystem
from string import punctuation
import pandas
import os
from razdel import sentenize, tokenize
from torch.utils.data import DataLoader
from sklearn.model_selection import KFold
import torch.nn.functional as F
import time
import torch
import torch.nn as nn
import numpy as np

mystem = Mystem() 
russian_stopwords = stopwords.words("russian")

#and token not in russian_stopwords
#and token != " "]
#and token.strip() not in punctuation]
        
def ntlk_preprocess_text(text):
    tokens = mystem.lemmatize(text.lower())
    tokens = [token.replace('\n', ' ').replace(' ', '') for token in tokens]
    tokens = [token for token in tokens if len(token) > 0 and token.strip() not in punctuation + '«' + '»' + '»,\xa0—' + ')']
    return tokens

def label_pipeline(label):
    possible = [0, -1, 1]
    return possible.index(label)

# %%
#NAVEC
from navec import Navec
from slovnet.model.emb import NavecEmbedding
navec = Navec.load('navec_hudlit_v1_12B_500K_300d_100q.tar')

def navec_text_pipeline(sentence):
    return list([navec[w] if w in navec else navec['<unk>'] for w in ntlk_preprocess_text(sentence)])

def navec_emb_text_pipeline(sentence, fixed_len=30):
    unk_index = navec.vocab.words.index('<unk>')
    index_list = list([navec.vocab.words.index(w) if w in navec else unk_index for w in ntlk_preprocess_text(sentence)])
    index_list = index_list + [unk_index for _ in range(fixed_len - len(index_list))]
    return index_list[:fixed_len]

# %%
from torch.utils.data import DataLoader

device = torch.device('cpu')

def collate_batch_to_sentence(batch):
    text_list = []
    for item in batch:
        distrbuted_repr = navec_text_pipeline(item[0]) #get list of embedded tokens
        distrbuted_repr = np.array(distrbuted_repr).mean(0) #aggregate into a single sentence vector
        text_list.append(distrbuted_repr)
    text_list = torch.tensor(text_list)
    label_list = torch.tensor([label_pipeline(item[5]) for item in batch])
    return text_list.to(device), label_list.to(device)

def collate_batch_to_navec_ids(batch):
    text_list = []
    for item in batch:
        navc_id_list = navec_emb_text_pipeline(item[0]) #get list of embedded tokens
        text_list.append(navc_id_list)
    text_list = torch.tensor(text_list)
    label_list = torch.tensor([label_pipeline(item[5]) for item in batch])
    return text_list.to(device), label_list.to(device)

# %%
class SingleLinearLayer(nn.Module):

    def __init__(self, embed_dim, num_class):
        super(SingleLinearLayer, self).__init__()
        self.fc = nn.Linear(embed_dim, num_class)
        self.init_weights()

    def init_weights(self):
        initrange = 0.5
        self.fc.weight.data.uniform_(-initrange, initrange)
        self.fc.bias.data.zero_()

    def forward(self, text):
        return self.fc(text)
    
class TextClassificationModel2Layer(nn.Module):

    def __init__(self, embed_dim, num_class):
        super(TextClassificationModel2Layer, self).__init__()
        self.fc1 = nn.Linear(embed_dim, 10000)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(10000, num_class)
        self.init_weights()

    def init_weights(self):
        initrange = 0.5
        self.fc1.weight.data.uniform_(-initrange, initrange)
        self.fc1.bias.data.zero_()
        self.fc2.weight.data.uniform_(-initrange, initrange)
        self.fc2.bias.data.zero_()

    def forward(self, text_bow):
        fc1_out = self.fc1(text_bow)
        relu_out = self.relu(fc1_out)
        return self.fc2(relu_out)
    
class CNN(nn.Module):
    def __init__(self, vocab_size, embedding_dim, n_filters, filter_sizes, output_dim, 
                 dropout, pad_idx):
        
        super().__init__()
                
        self.embedding = nn.Embedding(vocab_size, embedding_dim, padding_idx = pad_idx)
        
        self.convs = nn.ModuleList([
                                    nn.Conv2d(in_channels = 1, 
                                              out_channels = n_filters, 
                                              kernel_size = (fs, embedding_dim)) for fs in filter_sizes
                                    ])
        
        self.fc = nn.Linear(len(filter_sizes) * n_filters, output_dim)

        self.dropout = nn.Dropout(dropout)
        
    def forward(self, text):
        
        #text = [sent len, batch size]
        
        #text = text.permute(1, 0)
                
        #text = [batch size, sent len]
        
        embedded = self.embedding(text)

        #embedded = [batch size, sent len, emb dim]
        
        embedded = embedded.unsqueeze(1)
        
        #embedded = [batch size, 1, sent len, emb dim]
        
        conved = [F.relu(conv(embedded)).squeeze(3) for conv in self.convs]
        
        #conved_n = [batch size, n_filters, sent len - filter_sizes[n] + 1]
                
        pooled = [F.max_pool1d(conv, conv.shape[2]).squeeze(2) for conv in conved]
        
        #pooled_n = [batch size, n_filters]
        
        cat = self.dropout(torch.cat(pooled, dim = 1))

        #cat = [batch size, n_filters * len(filter_sizes)]
            
        return self.fc(cat)

t_vocab_size = len(navec.vocab.words)
t_embedding_dim = 300
t_n_filters = 3
t_filter_sizes = [3]
t_output_dim = 3
t_dropout = 0
t_pad_idx = None
model = CNN(t_vocab_size,
          t_embedding_dim,
          t_n_filters,
          t_filter_sizes,
          t_output_dim,
          t_dropout,
          t_pad_idx
         )

# %%
nn.Conv2d(in_channels = 1, out_channels = n_filters, kernel_size = (fs, embedding_dim)) for fs in filter_sizes

# %%
#memory heavy!
from gensim.models import KeyedVectors
keyed_model = KeyedVectors(navec.pq.dim)
weights = navec.pq.unpack()  # warning! memory heavy
keyed_model.add_vectors(navec.vocab.words, weights)

# %%
embedding = nn.Embedding.from_pretrained(torch.FloatTensor(weights))
model.embedding = embedding
for param in model.embedding.parameters():
    param.requires_grad = False

# %%
from sklearn.metrics import f1_score

def train(dataloader):
    model.train()
    total_acc, total_count = 0, 0
    log_interval = 2
    start_time = time.time()

    for idx, (text, label) in enumerate(dataloader):
        optimizer.zero_grad()
        predicted_label = model(text)
        loss = criterion(predicted_label, label)
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.1)
        optimizer.step()
        total_acc += (predicted_label.argmax(1) == label).sum().item()
        total_count += label.size(0)
        if idx % log_interval == 0 and idx > 0:
            elapsed = time.time() - start_time
            #print('| epoch {:3d} | {:5d}/{:5d} batches '
            #      '| accuracy {:8.3f}'.format(epoch, idx, len(dataloader),
            #                                  total_acc/total_count))
            total_acc, total_count = 0, 0
            start_time = time.time()
            

def evaluate(dataloader):
    model.eval()
    total_acc, total_count = 0, 0

    with torch.no_grad():
        for idx, (text, label) in enumerate(dataloader):
            predicted_label = model(text)
            label = label
            loss = criterion(predicted_label, label)
            total_acc += (predicted_label.argmax(1) == label).sum().item()
            total_count += label.size(0)
    return total_acc/total_count

# %%
BATCH_SIZE = 4
train_part = 0.8

train_path = os.path.join(os.getcwd(), "train_data.csv")
train_df = pandas.read_csv(train_path, sep="\t")

train_len = int(len(train_df) * train_part)
train_data = train_df.values[:train_len]
test_data = train_df.values[train_len:]

#gradient accum

#kfold=KFold(n_splits=k_folds,shuffle=True)
#for fold,(train_idx, val_idx) in enumerate(kfold.split(train_df.values)):
#print(f"=====fold number {fold}=====")
train_data = train_data#train_df.values[:int(len)]
test_data = test_data#train_df.values[val_idx]
train_dataloader = DataLoader(train_data, batch_size=BATCH_SIZE,
                              shuffle=False, collate_fn=collate_batch_to_navec_ids)
valid_dataloader = DataLoader(test_data, batch_size=BATCH_SIZE,
                              shuffle=False, collate_fn=collate_batch_to_navec_ids)

# %%
# Hyperparameters

EPOCHS = 3  # epoch
LR = 5  # learning rate
k_folds=5

criterion = torch.nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.5)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.1)

total_accu = None
for epoch in range(1, EPOCHS + 1):
    epoch_start_time = time.time()
    train(train_dataloader)
    accu_val = evaluate(valid_dataloader)
    if total_accu is not None and total_accu > accu_val:
        scheduler.step()
    else:
        total_accu = accu_val
    print('-' * 59)
    print('| end of epoch {:3d} | time: {:5.2f}s | '
          'valid accuracy {:8.3f} '.format(epoch,
                                           time.time() - epoch_start_time,
                                           accu_val))
    print('-' * 59)

# %%
val_path = os.path.join(os.getcwd(), "validation_data.csv")
val_df = pandas.read_csv(val_path, sep="\t")

# %%
def collate_batch_valid(batch):
    text_list = []
    for item in batch:
        distrbuted_repr = navec_text_pipeline(item[0]) #get list of embedded tokens
        distrbuted_repr = np.array(distrbuted_repr).mean(0) #aggregate into a single sentence vector
        text_list.append(distrbuted_repr)
    text_list = torch.tensor(text_list)
    return text_list.to(device)

# %%
predicted_label = model(collate_batch_valid(test_data))
true_labels = [data[5] for data in test_data]
argmaxed_validation = predicted_label.argmax(1)
test_result = [[0, -1, 1][index] for index in argmaxed_validation]
print(f1_score(true_labels, test_result, average='macro'))
# Out:
# 0.4272455158531108

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
cm = confusion_matrix(true_labels, test_result, labels=[1, 0, -1])
disp = ConfusionMatrixDisplay(confusion_matrix=cm,
                              display_labels=["1", "0", "-1"])
disp.plot()

# %%
f0_1_indeces = [index for (index, value) in enumerate(true_labels) if value == 1]
f0_1 = [fn_index for (value, fn_index) in zip(np.array(test_result)[f0_1_indeces], f0_1_indeces) if value == 0]
f0_1 = test_data[f0_1]

# %%
from sklearn import metrics
report = metrics.classification_report(true_labels, test_result)
print(report)
print("accuracy: {:0.3f}".format(metrics.accuracy_score(true_labels, test_result)))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.42      0.24      0.31       206
#            0       0.76      0.92      0.83       962
#            1       0.37      0.09      0.14       160
#
#     accuracy                           0.72      1328
#    macro avg       0.52      0.42      0.43      1328
# weighted avg       0.66      0.72      0.67      1328
#
# accuracy: 0.717

# %%
import eli5
eli5.show_weights(model, top=10)
# Out:
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#     <div style="background-color: #fdd; padding: 0.5em;">
#         Error: estimator SingleLinearLayer(
#   (fc): Linear(in_features=300, out_features=3, bias=True)
# ) is not supported
#     </div>

# %%
f0_1
# Out:
# array([['Победителем Кубка африканских наций впервые в своей истории стала сборная Замбии, неожиданно переигравшая в финале сборную Кот-д’Ивуара.',
#         'сборная Замбии', 'ORGANIZATION', 66, 80, 1],
#        ['В 2014 году дело было закрыто, но его возобновили в 2016 году после того, как Голстейн в интервью Fox News заявил, что убил талиба, задержанного в афганском районе Марджа, из опасений, что, если его отпустят на свободу, он будет нападать на афганцев, помогающих американским военным.',
#         'афганцев', 'NATIONALITY', 241, 249, 1],
#        ['Выдвижения кандидатуры Керри, представляющего в Сенате штата Массачусетс и номинировавшегося на пост президента в 2004 году, ожидалось еще с прошлой недели, когда представитель США в ООН Сьюзан Райс попросила президента Обаму снять ее кандидатуру.',
#         'Обаму', 'PERSON', 220, 225, 1],
#        ['Правительство Италии надеется, что меры жесткой экономии позволят успокоить инвесторов, опасающихся, что Италия станет следующей жертвой европейского долгового кризиса.',
#         'Италия', 'COUNTRY', 105, 111, 1],
#        ['Радикальная партия находится в номинальной оппозиции правительству, хотя ранее также выражала готовность работать с ним.',
#         'Радикальная партия', 'ORGANIZATION', 0, 18, 1],
#        ['Как сообщил The Hollywood Reporter в конце сентября 2014 года, британский актёр Мэтт Смит, исполняющий роль Одиннадцатого Доктора в британском телесериале «Доктор Кто», сыграет в экранизации романа американского писателя Сета Грэма-Смита «Гордость и предубеждение и зомби», которая является вольной интерпретацией классического произведения англичанки Джейн Остин, священника мистера Коллинза.',
#         'Одиннадцатого Доктора', 'PERSON', 108, 129, 1],
#        ['Выражаю признательность родителям и педагогам юных героев, ведь нравственное и патриотическое воспитание, формирование у детей ответственного гражданского поведения, милосердия, мужества и смелости – это их заслуга.',
#         'педагогам', 'PROFESSION', 36, 45, 1],
#        ['«Это как мое последнее желание\xa0— увидеть Rolling Stones», сказал Хоакин.',
#         'Rolling Stones', 'ORGANIZATION', 41, 55, 1],
#        ['Связанное с Исламским государством агентство Amaq назвало Шекатта своим «солдатом», который «осуществил эту операцию в ответ на призывы сделать мишенью граждан стран коалиции».',
#         'Исламским государством', 'ORGANIZATION', 12, 34, 1],
#        ['Пришедшие на «Кубок Поморья» северяне смогли также насладиться дефиле восточного костюма, которое представили им очаровательные модели из агентства CENTERUM: Анастасия Шкуренко, Анастасия Большакова, Вероника Платонова, Даша Турова.',
#         'Анастасия Шкуренко', 'PERSON', 158, 176, 1],
#        ['Марчевский призвал не пускать «Оно» в отечественный прокат: «Мы должны охранять наши святыни, нашу культуру, в том числе ее символы радости\xa0— клоунов и цирк».',
#         'Марчевский', 'PERSON', 0, 10, 1],
#        ['Официальные поздравления в адрес мастера портрета направили, в том числе, президент Республики Беларусь Александр Лукашенко и Мэр Москвы Сергей Собянин.',
#         'Сергей Собянин', 'PERSON', 137, 151, 1],
#        ['Wallmart в 2008 году получил чистую прибыль в 13,4\xa0млрд долларов США, оборот компании в 2010 году составил 408,1\xa0млрд долларов США.',
#         'Wallmart', 'ORGANIZATION', 0, 8, 1],
#        ['Официальный представитель Талибана Забиулла Муджахид у себя в твиттере утверждает, что в результате атаки талибов в деревне Ахунд Баба в районе Бараки Барак были убиты «5 американских захватчиков и 9 наёмников», со стороны талибов погибло «2 муджахида».',
#         'талибов', 'ORGANIZATION', 223, 230, 1],
#        ['Поэтому мы обязаны обеспечить детям различные платформы для самореализации»,\xa0— сказал депутат.',
#         'депутат', 'PROFESSION', 86, 93, 1],
#        ['В частностив день 60-летия Путина 7 октября 2012 года в ходе программы «Вестей недели» Дмитрий Киселёв посвятил этому событию комментарий длительностью 12 минут 41 секунду:',
#         'Путина', 'PERSON', 27, 33, 1],
#        ['Рокфеллер также основал несколько международных и благотворительных организаций: Americas Society, влиятельную Трёхстороннюю комиссию и некоммерческую организацию помощи малообеспеченным ньюйоркцам New York City Partnership.',
#         'New York City Partnership', 'ORGANIZATION', 198, 223, 1],
#        ['На референдум прибыли многие видные политики и государственные деятели, включая экс-президента Джимми Картера, а также несколько тысяч международных наблюдателей.',
#         'государственные деятели', 'PROFESSION', 47, 70, 1],
#        ['интервью агентству Интерфакс 27 декабря 2011 при отставке с поста замглавы Администрации Президента России Сурков утверждал, что: «Я был в числе тех, кто помогал президенту Ельцину осуществить мирный переход власти.',
#         'Ельцину', 'PERSON', 173, 180, 1],
#        ['Эксперты отмечают, что у Canucks лучше построена игра в большинстве\xa0— по игре в большинстве они третьи в плей-офф (и лучшие среди команд, прошедших первый раунд), а у Bruins\xa0— 14-ый результат (худший среди команд, вышедших во второй круг).',
#         'Canucks', 'ORGANIZATION', 25, 32, 1],
#        ['В заявку сборной России под руководством Владимира Кузюткина попали связующие Вера Улякина и Евгения Старцева, нападающие Леся Махно, Любовь Соколова, Наталья Гончарова, Ольга Фатеева, Екатерина Гамова и Татьяна Кошелева, блокирующие Мария Борисенко (капитан команды), Мария Перепёлкина, Елена Константинова и Юлия Меркулова и два либеро Светлана Крючкова и Екатерина Кабешова.',
#         'Мария Борисенко', 'PERSON', 234, 249, 1],
#        ['Войны не будет: Трамп заинтересован в мирном разрешении кризиса c КНДР',
#         'Трамп', 'PERSON', 16, 21, 1],
#        ['Президент Саркози выразил в этой связи надежду на то, что ему удастся за время председательства в G-20 провести целый ряд реформ.',
#         'G-20', 'ORGANIZATION', 98, 102, 1],
#        ["Организаторами экспозиции являются отделение испанского банка ''La Caixa''\xa0— ''Obra Social La Caixa'', шотландская компания ''Nomad Exhibitions'' и ''Museo de Nankin'', чьи старания позволили выставке путешествовать по миру.",
#         'Museo de Nankin', 'ORGANIZATION', 150, 165, 1],
#        ['Слова Хейла сохранили актуальность, воплотившись в 1976 году в устав «Голоса Америки», который обязывает его работников «служить надёжным и авторитетным источником новостей».',
#         'Хейла', 'PERSON', 6, 11, 1],
#        ['В заявлении он также осуждал решение президента Дональда Трампа «отдать Аль-Кудс евреям» (признание Иерусалима столицей Израиля) и критиковал «кафиров в националистическом безбожном обществе».',
#         'Аль-Кудс', 'PERSON', 72, 80, 1],
#        ['Матч запомнился не только звездной игрой Стосур, но и недостойным поведением Уильямс.',
#         'Стосур', 'PERSON', 41, 47, 1],
#        ['Столичный градоначальник Сергей Собянин в своём микроблоге в Twitter в отметил, что Александр Шилов запечатлел эпоху через разные образы людей:',
#         'Александр Шилов', 'PERSON', 84, 99, 1],
#        ['В заявку сборной России под руководством Владимира Кузюткина попали связующие Вера Улякина и Евгения Старцева, нападающие Леся Махно, Любовь Соколова, Наталья Гончарова, Ольга Фатеева, Екатерина Гамова и Татьяна Кошелева, блокирующие Мария Борисенко (капитан команды), Мария Перепёлкина, Елена Константинова и Юлия Меркулова и два либеро Светлана Крючкова и Екатерина Кабешова.',
#         'Наталья Гончарова', 'PERSON', 151, 168, 1],
#        ['В свою очередь, главным претендентом на пост директора по производственным активам является земляк Баффета Дэвид Сокол.',
#         'Дэвид Сокол', 'PERSON', 107, 118, 1],
#        ['57% респондентов полагают, что президент не нарушает конституцию и может назначить Иржи Руснока премьером',
#         'президент', 'PROFESSION', 31, 40, 1],
#        ['Позже, в интервью газете Nice Matin Бриджит Бардо подробнее рассказала о причинах своего предполагаемого переезда в Россию.',
#         'Россию', 'COUNTRY', 116, 122, 1],
#        ['После службы в ВМС с 1979 года работал в госкорпорации CITIC, созданной с одобрения Дэн Сяопина.',
#         'CITIC', 'ORGANIZATION', 55, 60, 1],
#        ['Ведь именно в этих странах проживает аудитория, которая до сих пор не выходит в Сеть, а значит - не пользуется Google.',
#         'Google', 'ORGANIZATION', 111, 117, 1],
#        ['Вадим, как опытный литератор, объяснял смыслы и темы своего творчества, говорил про два мира на альбоме\xa0— реальный и магический, про чередование лейтмотивов, таких как «друг», «мост», «любовь\xa0— та, с кем на одной стороне моста».',
#         'Вадим', 'PERSON', 0, 5, 1],
#        ['Американский представитель при ООН Джон Болтон (John Bolton) приветствовал российско-китайский проект как шаг вперёд.',
#         'российско', 'COUNTRY', 75, 84, 1],
#        ['Сейчас я хочу публично поблагодарить свою семью и невероятную команду врачей за все то, что они для меня сделали до и после операции.',
#         'врачей', 'PROFESSION', 70, 76, 1],
#        ['По сюжету, Елизавета вместе с мужем Глебом готовятся отпраздновать 30-летнюю годовщину свадьбы, но даже и в такой день вторгаются неизбежные заботы, связанные с благотворительным фондом.',
#         'Елизавета', 'PERSON', 11, 20, 1],
#        ['Завод закрыт несмотря на растущие прибыли компании, фокусируясь на продажу в Китай в связи с падением спроса в Северной Европе.',
#         'Китай', 'COUNTRY', 77, 82, 1],
#        ['25 мальчиков и девочек разыграли сценку в которой войны Израиля спасали мирных жителей Израиля и Ливана от ракет королевства террористической организации «Хизбалла», представляющий в спектакле отрицательных персонажей поработивших царство цветов и препятствующих миру во всём мире.',
#         'Ливана', 'COUNTRY', 97, 103, 1],
#        ['Первый матч ЦСКА провёл с молодежной сборной провинции Цзянсу и одержал разгромную победу, отправив в чужие ворота четыре мяча.',
#         'ЦСКА', 'ORGANIZATION', 12, 16, 1],
#        ['В заявку сборной России под руководством Владимира Кузюткина попали связующие Вера Улякина и Евгения Старцева, нападающие Леся Махно, Любовь Соколова, Наталья Гончарова, Ольга Фатеева, Екатерина Гамова и Татьяна Кошелева, блокирующие Мария Борисенко (капитан команды), Мария Перепёлкина, Елена Константинова и Юлия Меркулова и два либеро Светлана Крючкова и Екатерина Кабешова.',
#         'Вера Улякина', 'PERSON', 78, 90, 1],
#        ['Медаль будет вручена профессору Хокингу 30 ноября, в очередную годовщину Королевского Общества, которое было основано в 1660 году.',
#         'Хокингу', 'PERSON', 32, 39, 1],
#        ['Там Александра и Антон заняли первое место и, в качестве главного приза, выиграли поездку на Чемпионат Мира от благотворительного фонда "Независимость".',
#         'Александра', 'PERSON', 4, 14, 1],
#        ['80-летний Уоррен Баффет за минувший год увеличил свой капитал на 5 млрд долларов.',
#         'Уоррен Баффет', 'PERSON', 10, 23, 1],
#        ['Помпео обсудил диверсификацию энергоснабжения с главой МИД Словении',
#         'главой МИД Словении', 'PROFESSION', 48, 67, 1],
#        ["К ним присоединяются также Прюдо'мм и Альберт II.", "Прюдо'мм",
#         'PERSON', 27, 35, 1],
#        ['Александр был самым сложным соперником в моей карьере, он был фаворитом и он это доказал.',
#         'Александр', 'PERSON', 0, 9, 1],
#        ['Главными фаворитами турнира считаются бразильянки.',
#         'бразильянки', 'NATIONALITY', 38, 49, 1],
#        ['Хитто получил 35 из 48 голосов членов оппозиционной коалиции на совещании, которое прошло в Турции во вторник.',
#         'Хитто', 'PERSON', 0, 5, 1],
#        ['Всего на борту воздушного судна находились 32 человека, среди которых были представители миссии Организации Объединённых Наций и миротворцы призванные в ДРК с целью защиты мирного населения в условиях затяжной гражданской войны, которая продолжается в стране с 1998 годаРазбившимся в Конго самолетом управлял грузинский экипаж.',
#         'миротворцы', 'PROFESSION', 129, 139, 1],
#        ['17% поддерживают вариант технического правительства Руснока, для 21% приемлемо продолжение коалиционного кабинета OSD-TOP 09 с премьером Мирославой Немцовой.',
#         'технического правительства', 'ORGANIZATION', 25, 51, 1],
#        ['Во второй 45-минутке россияне создали несколько опаснейших моментов, однако мяч отказывался лететь в сетку ворот греческого голкипера Михалиса Сифакиса.',
#         'россияне', 'NATIONALITY', 21, 29, 1],
#        ['Facebook уже обошел Google по общему объему интернет-трафика и стремительно догоняет по количеству пользователей.',
#         'Facebook', 'ORGANIZATION', 0, 8, 1],
#        ['Презентацию глянца нового формата посетили известные в Украине и за её пределами художники, именитые дизайнеры и звёздные гости: Диана Агаян, Александра Кормилицына, Юлия Богдан, Алексей и Виктория Лебедько, Танака Икуко, Елена Гребенюк, Константин Зубач, Андрей Кише (Kishe), Владлена Сопко, Поль Манондиз и ведущая телепроекта «Все буде добре» Надежда Матвеева.',
#         'художники', 'PROFESSION', 81, 90, 1],
#        ['МТБЮ выдвигает обвинения как против Младича, так и против его бывшего союзника\xa0— бывшего политического лидера боснийских сербов Радована Караджича.',
#         'Радована Караджича', 'PERSON', 128, 146, 1],
#        ['В ней главную роль играет сюжет с Лэнсом Армстронгом, который также участвует в презентации в составе команды "Астана".',
#         'Лэнсом Армстронгом', 'PERSON', 34, 52, 1],
#        ['Из-за греческой позиции официальное название Македонии в ООН с 1993 года\xa0— «бывшая югославская республика Македония», а Греция блокирует ее вступление в Евросоюз и НАТО.',
#         'НАТО', 'ORGANIZATION', 164, 168, 1],
#        ['Кроме художественной прозы писал сатирические монологи, юморески и сценарии для номеров, с которыми выступали на эстраде известные советские и российские юмористы, а также сам Арканов.',
#         'Арканов', 'PERSON', 176, 183, 1],
#        ['Оставшиеся в живых пассажиры благодарят членов экипажа за слаженную работу и утверждают, что спаслись только благодаря им.',
#         'членов экипажа', 'PROFESSION', 40, 54, 1],
#        ["Организаторами экспозиции являются отделение испанского банка ''La Caixa''\xa0— ''Obra Social La Caixa'', шотландская компания ''Nomad Exhibitions'' и ''Museo de Nankin'', чьи старания позволили выставке путешествовать по миру.",
#         'Obra Social La Caixa', 'ORGANIZATION', 79, 99, 1],
#        ['В номинации HUMANITAS победила книга «Советский художественный авангард: Инскрипты книжного собрания РГАЛИ» («Центр книги Рудомино»).',
#         'Центр книги Рудомино', 'ORGANIZATION', 110, 130, 1],
#        ['Когда вы рассказываете о пуленепробиваемом человеке, то вам нужен пуленепробиваемый, надежный режиссер.',
#         'режиссер', 'PROFESSION', 94, 102, 1],
#        ['25 мальчиков и девочек разыграли сценку в которой войны Израиля спасали мирных жителей Израиля и Ливана от ракет королевства террористической организации «Хизбалла», представляющий в спектакле отрицательных персонажей поработивших царство цветов и препятствующих миру во всём мире.',
#         'Израиля', 'COUNTRY', 87, 94, 1],
#        ['Global Times пишет, что на Островах живут «тысячи китайцев», а в столице Хониара около 70\xa0% магазинов принадлежат китайцам.',
#         'китайцев', 'NATIONALITY', 50, 58, 1],
#        ['В этом году Сальвадор стал третьей страной\xa0— после Доминиканской Республики и Буркина-Фасо\xa0— которая разорвала отношения с Тайванем в пользу Китая.',
#         'Китая', 'COUNTRY', 141, 146, 1],
#        ['Грубо на правом краю защиты ошибся Денисов, и капитан греков Карагунис (проводивший 120 матч за сборную), ворвавшись в штрафную россиян, мощно пробил под Малафеевa\xa0— 0:1.',
#         'Карагунис', 'PERSON', 61, 70, 1],
#        ['Обращаясь к десяткам тысяч человек, присутствовавшим на мессе на площади Святого Петра, понтифик сказал, что хочет, чтобы этот сбор стал «жестом благотворительности, который не только облегчит материальные страдания, но и продемонстрирует мою личную близость и близость всей церкви» к народу Украины.',
#         'понтифик', 'PROFESSION', 88, 96, 1],
#        ['А вот удар Стоппила Сунзу был точен, он и принёс Замбии историческую победу.',
#         'Замбии', 'COUNTRY', 49, 55, 1],
#        ['В конце эпизода, Иисус, вопреки общественному мнению, принимает допинг и в очередной раз «спасает» вымышленный городок.',
#         'Иисус', 'PERSON', 17, 22, 1],
#        ['С.Дарькин занимает пост губернатора Приморского края уже более 10 лет.',
#         'губернатора Приморского края', 'PROFESSION', 24, 52, 1],
#        ['Турецкое военное командование разработало новую военно-морскую стратегию, названную «Операция Барбаросса — Эгейский щит» в честь средневекового адмирала Хайр-ад-Дина Барбароссы.',
#         'Хайр-ад-Дина Барбароссы', 'PERSON', 153, 176, 1],
#        ['Тем самым Национальное собрание Венесуэлы исполнило просьбу вице-президента страны Николаса Мадуро об отсрочке инаугурации Уго Чавеса.',
#         'Николаса Мадуро', 'PERSON', 83, 98, 1],
#        ['Она училась в Иллинойсском университете в Урбане-Шампейне, изучая урожайность и надеясь стать профессором в области сельского хозяйства.',
#         'профессором в области сельского хозяйства', 'PROFESSION', 94,
#         135, 1],
#        ['Дилайл, опустошённый тем, что начал распадаться его брак, в 2007 году пришел в посольство России в Оттаве и предложил продать секретную информацию.',
#         'Дилайл', 'PERSON', 0, 6, 1],
#        ['Кроме того, военные обеих стран проведут совместные мероприятия для укрепления дружбы, а контр-адмирал Гуан Байлин посетит военные объекты Джибути.',
#         'военные', 'PROFESSION', 12, 19, 1],
#        ['Перед началом матча явным фаворитам считались ивуарийцы, в составе которых выступают такие звёзды английской Премьер-лиги как Дидье Дрогба, Саломон Калу, Коло Туре, Яя Туре.',
#         'ивуарийцы', 'NATIONALITY', 46, 55, 1],
#        ['Поэтому верхушка ODS очень быстро договорилась и уже в четверг 20 июня выдвинула своего кандидата на пост премьер-министра - председателя нижней палаты парламента Мирославу Немцову (1952 года рожд.).',
#         'Мирославу Немцову', 'PERSON', 163, 180, 1],
#        ['Меркель исключает возможность военных действий.', 'Меркель',
#         'PERSON', 0, 7, 1],
#        ['Елизавета Глинка, врач-реаниматолог по образованию, была известна своей правозащитной и благотворительной деятельностью.',
#         'Елизавета Глинка', 'PERSON', 0, 16, 1],
#        ['На пост министра внутренних дел в техническом кабинете Руснока готовят Мартина Пецина, исполнявшего уже эти обязанности в беспартийном правительстве Яна Фишера в 2009-2010 годах.',
#         'Мартина Пецина', 'PERSON', 71, 85, 1],
#        ['Он реализовал пенальти на 52-й минуте и затем показал руками номер Брайанта\xa0— 24.',
#         'Брайанта', 'PERSON', 67, 75, 1],
#        ['Сенатор заслужил высокую оценку представителей администрации Обамы, когда произнес речь о проблемах национальной безопасности на национальном съезде Демократической партии, прошедшем в августе этого года.',
#         'Сенатор', 'PROFESSION', 0, 7, 1],
#        ['Глава правящего в Египте Высшего совета вооруженных сил маршал Хусейн Тантави поручил бывшему премьер-министру Камалю аль-Ганзури сформировать новый кабинет министров, сообщил спутниковый телеканал "Аль-Джазира".',
#         'кабинет министров', 'ORGANIZATION', 149, 166, 1],
#        ['В марте Китай сообщал, что передал Венесуэле 65 тонн медицинской помощи.',
#         'Китай', 'COUNTRY', 8, 13, 1],
#        ['Презентацию глянца нового формата посетили известные в Украине и за её пределами художники, именитые дизайнеры и звёздные гости: Диана Агаян, Александра Кормилицына, Юлия Богдан, Алексей и Виктория Лебедько, Танака Икуко, Елена Гребенюк, Константин Зубач, Андрей Кише (Kishe), Владлена Сопко, Поль Манондиз и ведущая телепроекта «Все буде добре» Надежда Матвеева.',
#         'дизайнеры', 'PROFESSION', 101, 110, 1],
#        ['В Словакию, по мнению Земана, должна отправиться супруга экс-президента Чехии Ливия Клаусова.',
#         'Ливия Клаусова', 'PERSON', 78, 92, 1],
#        ['Сборная Кот-д’Ивуара с самого начал турнира имела статус фаворита.',
#         'Сборная Кот-д’Ивуара', 'ORGANIZATION', 0, 20, 1],
#        ['Еще одним из наиболее вероятных кандидатов на президентский пост является 60-летний Модибо Сидибе (Modibo Sidibe).',
#         'Модибо Сидибе', 'PERSON', 84, 97, 1],
#        ["В треке ''Bad Husband'' он читает об отношениях с бывшей женой, в треке ''Untouchable'' он критикует нынешнего президента США Дональда Трампа, а в треке ''Castle'' он извиняется перед своей дочерью Хейли.",
#         'Хейли', 'PERSON', 198, 203, 1],
#        ['23 января 2020 года во время визита в Израиль Владимир Путин встретился с матерью девушки Яффой Иссахар, которая также попросила его о помиловании дочери.',
#         'Владимир Путин', 'PERSON', 46, 60, 1],
#        ['Чулпан Хаматова сыграет главную роль в фильме про Доктора Лизу',
#         'Лизу', 'PERSON', 58, 62, 1],
#        ['В частности, бывший министр здравоохранения Клод Эвин, участвовавший в его разработке, подверг редактирование изображений Сартра и Тати критике, назвав «абсурдом».',
#         'Тати', 'PERSON', 131, 135, 1],
#        ['Все-таки он прошел под знаменем соцсети Facebook, основатель которой Марк Цукерберг стал человеком года по версии влиятельного американского журнала Time.',
#         'Time', 'ORGANIZATION', 149, 153, 1],
#        ['Российская сборная в очередной, 28-й раз стала победительницей в общекомандном зачёте на чемпионатах мира по самбо.',
#         'Российская сборная', 'ORGANIZATION', 0, 18, 1],
#        ['В 2018 году премьер-министр Эфиопии и президент Эритреи Исайяс Афеверки заключили мирный договор и договорились сотрудничать в нескольких сферах, в том числе в экономической.',
#         'премьер-министр Эфиопии', 'PROFESSION', 12, 35, 1],
#        ['Ещё бы, ведь в ней выступают такие звёзды современного футбола как Дидье Дрогба, Саломон Калу, Коло Туре, Яя Туре и другие.',
#         'Саломон Калу', 'PERSON', 81, 93, 1],
#        ['Марчевский призвал не пускать «Оно» в отечественный прокат: «Мы должны охранять наши святыни, нашу культуру, в том числе ее символы радости\xa0— клоунов и цирк».',
#         'клоунов', 'PROFESSION', 142, 149, 1],
#        ['Керри сыграл также видную роль в восстановлении дипломатических отношений между США и Вьетнамом.',
#         'Керри', 'PERSON', 0, 5, 1],
#        ['Спикер Национальной Ассамблеи Диосдадо Кабельо прочел письмо к законодателям, в котором заявил, что врачи рекомендовали Чавесу не отправляться пока домой.',
#         'Чавесу', 'PERSON', 120, 126, 1],
#        ['Тони Сопрано любил свою жену Кармелу, был заботливым отцом, и в то же время поддерживал несколько внебрачных связей.',
#         'Тони Сопрано', 'PERSON', 0, 12, 1],
#        ['Канадский морской офицер, который признался в том, что сотрудничал с российскими спецслужбами в течение 4 лет, был приговорен к 20 годам в тюрьме.',
#         'российскими спецслужбами', 'ORGANIZATION', 69, 93, 1],
#        ['Фолл неоднократно писал заявления в полицию по поводу того, что Макафи часто стрелял из своего ружья, а также из-за агрессивного поведения его собак.',
#         'полицию', 'ORGANIZATION', 36, 43, 1],
#        ['Друзья Арканова скорбят о потере и приносят соболезнования родным.',
#         'Арканова', 'PERSON', 7, 15, 1],
#        ['И Богородица выполнила обещание: в годы войны, когда председатель командовал партизанским обрядом, он попал в плен, но не был расстрелян и остался жив, что само по себе было чудом.',
#         'Богородица', 'PERSON', 2, 12, 1],
#        ['В 2018 году премьер-министр Эфиопии и президент Эритреи Исайяс Афеверки заключили мирный договор и договорились сотрудничать в нескольких сферах, в том числе в экономической.',
#         'Исайяс Афеверки', 'PERSON', 56, 71, 1],
#        ['Кроме Майкла Мура, в проектах могут принять участие такие известные режиссеры, как Стивен Гэган, Джон Камерон Митчел, Роланд Эммерих, снявший фильм-катастрофу «2012», и создатели картины «Социальная сеть» Аарон Соркин и Девид Финчер.',
#         'режиссеры', 'PROFESSION', 68, 77, 1],
#        ['17% поддерживают вариант технического правительства Руснока, для 21% приемлемо продолжение коалиционного кабинета OSD-TOP 09 с премьером Мирославой Немцовой.',
#         'коалиционного кабинета', 'ORGANIZATION', 91, 113, 1],
#        ['Западные СМИ сообщают, что в числе пяти основных фаворитов гонки находится, в частности, бывший премьер Ибрахим Бубакар Кейта (Ibrahim Boubacar Keita).',
#         'Ибрахим Бубакар Кейта', 'PERSON', 104, 125, 1],
#        ['Владимир Квачков\xa0— полковник ГРУ в отставке, воин-интернационалист, кавалер двух орденов Мужества, ордена Красной Звезды и других наград.',
#         'Владимир Квачков', 'PERSON', 0, 16, 1],
#        ['Власти Парагвая объявили трёхдневный траур в связи с гибелью политика.',
#         'политика', 'PROFESSION', 61, 69, 1],
#        ['— Мы намерены и в будущем поощрять посещение израильтянами Новой Зеландии с помощью недавно подписанного нами договора о праве на работу в этой стране для израильских туристов».',
#         'Новой Зеландии', 'COUNTRY', 59, 73, 1],
#        ['«Он погиб мученической смертью, защищая республику»,\xa0— заявил лидер Всеобщего народного конгресса Файка аль-Саид, обвинив в убийстве Салеха мятежников-хути (хуситами\xa0— шиитскими повстанцами).',
#         'Салеха', 'PERSON', 133, 139, 1],
#        ['Иисус Христос потребовал свободы Pussy Riot в новом эпизоде «Южного парка» (смотреть)',
#         'Иисус Христос', 'PERSON', 0, 13, 1],
#        ['После прекрасной передачи партнера, разрезавшей российскую оборону надвое, чешский нападающий Вацлав Пиларж вышел один на один с Малафеевым и без труда сократил отставание своей команды от россиян\xa0— 2:1.',
#         'Вацлав Пиларж', 'PERSON', 94, 107, 1],
#        ['Его адвокат заявил агентству Reuters, что он будет оспаривать выдвинутые обвинения и ищет возможные нарушения при аресте Смилянца в 2012 году в Нидерландах.',
#         'Смилянца', 'PERSON', 121, 129, 1],
#        ['Робел Филлипос\xa0— приятель Джохара Царнаева\xa0— был выпущен под залог в 100 тысяч долларов.',
#         'Джохара Царнаева', 'PERSON', 26, 42, 1],
#        ['Сразу после боя Александр Усик сказал журналистам:',
#         'Александр Усик', 'PERSON', 16, 30, 1],
#        ['После забитого гола россияне еще больше активизировались и через девять минут удвоили свое преимущество.',
#         'россияне', 'NATIONALITY', 20, 28, 1],
#        ['«Балогодарен Палате представителей штата Массачусетс за принятие резолюции, поддерживающей независимость Арцаха.',
#         'Палате представителей штата Массачусетс', 'ORGANIZATION', 13,
#         52, 1],
#        ['Гран-при получила вокалистка Вероника Карнаухова, а школа где она учится, — 11 ноутбуков для компьютерного класса.',
#         'Вероника Карнаухова', 'PERSON', 29, 48, 1],
#        ['Административный суд Кёльна снял с последнего альбома немецкой индастриал-метал группы Rammstein «Liebe ist für alle da» все ограничения на реализацию.',
#         'Rammstein', 'ORGANIZATION', 87, 96, 1],
#        ["я решила просить российского гражданства, чтобы покинуть эту страну, которая стала не чем иным, как кладбищем для животных»'',\xa0— заявила актриса.",
#         'российского', 'COUNTRY', 17, 28, 1],
#        ['В заявлении британского правительства говорится, что по оценке Национального центра кибербезопасности (NCSC), кибератаку «почти наверняка» провело ГРУ.',
#         'Национального центра кибербезопасности', 'ORGANIZATION', 63,
#         101, 1],
#        ['В заявку сборной России под руководством Владимира Кузюткина попали связующие Вера Улякина и Евгения Старцева, нападающие Леся Махно, Любовь Соколова, Наталья Гончарова, Ольга Фатеева, Екатерина Гамова и Татьяна Кошелева, блокирующие Мария Борисенко (капитан команды), Мария Перепёлкина, Елена Константинова и Юлия Меркулова и два либеро Светлана Крючкова и Екатерина Кабешова.',
#         'Екатерина Кабешова', 'PERSON', 358, 376, 1],
#        ['Как заявила председатель Норвежского нобелевского комитета Берит Рейсс-Андерсен в пятницу, 5 октября 2018 года, Муквеге и Мурад «внесли важный вклад в привлечение внимание к таким военным преступлениям и борьбу с ними».',
#         'Муквеге', 'PERSON', 112, 119, 1],
#        ['Пиотровский занимает активную социальную позицию, участвует в общественных делах русского культурного центра, о своих действиях искренне сожалеет, акт вандализма произошел случайно, на эмоциях.',
#         'русского культурного центра', 'ORGANIZATION', 81, 108, 1],
#        ['— Мы намерены и в будущем поощрять посещение израильтянами Новой Зеландии с помощью недавно подписанного нами договора о праве на работу в этой стране для израильских туристов».',
#         'израильтянами', 'NATIONALITY', 45, 58, 1],
#        ['С раннего возраста Браудер активно работал на пересечении технологий и прав человека.',
#         'Браудер', 'PERSON', 19, 26, 1],
#        ['Его адвокат заявил агентству Reuters, что он будет оспаривать выдвинутые обвинения и ищет возможные нарушения при аресте Смилянца в 2012 году в Нидерландах.',
#         'адвокат', 'PROFESSION', 4, 11, 1],
#        ['Выступление легендарного рокера прошло в магазине Доме Культуры (ММ ДК).',
#         'рокера', 'PROFESSION', 25, 31, 1]], dtype=object)

# %%
'Wallmart в 2008 году получил чистую прибыль в 13,4\xa0млрд долларов США, оборот компании в 2010 году составил 408,1\xa0млрд долларов США.'

# %%
predicted_label = model(collate_batch_valid(val_df.values))
argmaxed_validation = predicted_label.argmax(1)
valid_result = [[0, -1, 1][index] for index in argmaxed_validation]

# %%
d = {'col1': valid_result}
df = pandas.DataFrame(data=d)

# %%
df.to_csv(os.path.join(os.getcwd(), "result_linear2.csv"))

# %%
from collections import Counter
inp = inp
filtered = [c for c in inp if c not in [' ', '\n']]
counter = Counter(filtered)
max_val = max(counter.values())
c_list = list(counter.keys())
c_list.sort()
counter_len = len(counter)
strings = [['#' for _ in range(counter[char])] + [' ' for _ in range(max_val - counter[char])] for char in c_list]
strings_T = [['' for _ in range(len(counter))] for _ in range(max_val)]
for row_id in range(len(strings)):
    for col_id in range(len(strings[row_id])):
        strings_T[max_val - col_id - 1][row_id] = strings[row_id][col_id]
strings_T.append("".join(c_list))
custom = ["".join(t_row) for t_row in strings_T]
print('\n'.join(custom))
